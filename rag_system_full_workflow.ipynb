# %%
# --- Installation Commands (Run this once in a fresh Jupyter cell) ---
# IMPORTANT: Run these commands at the very beginning of your notebook
# or in your terminal (after activating your conda env if applicable).
# After successful installation, you might need to restart your Jupyter kernel
# and run all cells from the beginning.
#
#!pip install langchain-openai
#!pip install requests
#!pip install chromadb
#!pip install langchain
#!pip install langchain-community
# !pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-5.7.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from pypdf) (4.14.0)
# Downloading pypdf-5.7.0-py3-none-any.whl (305 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-5.7.0

# %%
import os
import shutil
import requests
import json

# LangChain Imports
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_core.embeddings import Embeddings
from langchain_community.vectorstores import Chroma
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain

# %%
# Custom Embeddings Class for Nutanix Granite Embedding API
# This class wraps your API endpoint to work seamlessly with LangChain's embedding interface.
class NutanixGraniteEmbeddings(Embeddings):
    """
    Custom Embeddings class to interact with the Nutanix AI Granite Embedding endpoint.
    It extends LangChain's Embeddings base class to provide custom embedding logic.
    """
    def __init__(self, api_key: str, endpoint_url: str, model_name: str):
        self.api_key = api_key
        self.endpoint_url = endpoint_url
        self.model_name = model_name
        self.session = requests.Session()

    def embed_documents(self, texts: list[str]) -> list[list[float]]:
        """
        Embeds a list of documents.
        """
        return self._get_embeddings(texts)

    def embed_query(self, text: str) -> list[float]:
        """
        Embeds a single query string.
        """
        return self._get_embeddings([text])[0]

    def _get_embeddings(self, texts: list[str]) -> list[list[float]]:
        """
        Internal helper method to make the actual API call.
        """
        headers = {
            "Authorization": f"Bearer {self.api_key}",
            "accept": "application/json",
            "Content-Type": "application/json"
        }
        payload = {
            "model": self.model_name,
            "input": texts,
            "encoding_format": "float"
        }

        response = None
        try:
            response = self.session.post(self.endpoint_url, headers=headers, json=payload)
            response.raise_for_status()
            result = response.json()

            if "data" in result and len(result["data"]) > 0:
                embeddings = [item["embedding"] for item in result["data"]]
                return embeddings
            else:
                raise ValueError("API response did not contain expected 'data' or embeddings.")

        except requests.exceptions.RequestException as e:
            print(f"API request failed: {e}")
            if response is not None:
                print(f"Response status: {response.status_code}")
                print(f"Response text: {response.text}")
            raise
        except json.JSONDecodeError:
            print(f"Failed to decode JSON from API response: {e}")
            raise
        except Exception as e:
            print(f"An unexpected error occurred during embedding: {e}")
            raise

# %%
os.environ["NUTANIX_API_KEY"] = "db076c5a-b4d9-44b5-bc93-0be3922df085"

# %%
# --- Configuration ---
PDF_DIR = "data/pdfs"
CHROMA_DB_DIR = "my_vector_db" # Directory for ChromaDB persistence

# Nutanix AI API Configuration
EMBEDDING_API_MODEL_NAME = "embedcpu"
NUTANIX_GRANITE_EMBEDDING_ENDPOINT = "https://ai.nutanix.com/api/v1/embeddings"
LLM_API_MODEL_NAME = "mobileyedemo"
NUTANIX_LLM_ENDPOINT = "https://ai.nutanix.com/api/v1" # Corrected base URL for ChatOpenAI

# IMPORTANT: Ensure NUTANIX_API_KEY environment variable is set.
NUTANIX_API_KEY = os.getenv("NUTANIX_API_KEY")

if not NUTANIX_API_KEY:
    print("WARNING: NUTANIX_API_KEY environment variable not set.")
    print("Please set this environment variable for the Nutanix AI APIs to work.")
    exit("API Key for Nutanix AI not found. Exiting.")

# %%
# --- 1. Prepare Directories ---
print("\n--- 1. Preparing Directories ---")
os.makedirs(PDF_DIR, exist_ok=True)
print(f"Ensuring PDF directory exists: {PDF_DIR}")

# IMPORTANT: Due to potential Windows PermissionError, it's recommended to MANUALLY
# delete the 'my_vector_db' folder if you encounter issues, or change CHROMA_DB_DIR
# if you want to regenerate the database.
if os.path.exists(CHROMA_DB_DIR):
    try:
        print(f"Attempting to remove existing ChromaDB data from: {CHROMA_DB_DIR}")
        shutil.rmtree(CHROMA_DB_DIR)
        print("Existing ChromaDB data removed successfully.")
    except PermissionError as e:
        print(f"PermissionError: Could not remove {CHROMA_DB_DIR}. Please close any programs accessing it and delete it manually.")
        print(f"Error details: {e}")
        exit("Cannot proceed without clearing old database. Please delete 'my_vector_db' manually or change CHROMA_DB_DIR.")
    except Exception as e:
        print(f"An unexpected error occurred while trying to remove {CHROMA_DB_DIR}: {e}")
        exit("Cannot proceed due to database cleanup error.")

os.makedirs(CHROMA_DB_DIR, exist_ok=True)
print(f"Ensuring ChromaDB directory exists: {CHROMA_DB_DIR}")
# Out:
# --- 1. Preparing Directories ---
# Ensuring PDF directory exists: data/pdfs
# Ensuring ChromaDB directory exists: my_vector_db

# %%
# --- 2. Load PDF Documents ---
print(f"\n--- 2. Loading PDF Documents from '{PDF_DIR}' ---")
documents = []
for filename in os.listdir(PDF_DIR):
    if filename.endswith(".pdf"):
        filepath = os.path.join(PDF_DIR, filename)
        try:
            loader = PyPDFLoader(filepath)
            documents.extend(loader.load())
            print(f"Loaded '{filename}'")
        except Exception as e:
            print(f"Error loading '{filename}': {e}")

if not documents:
    print(f"No PDF documents found in '{PDF_DIR}'. Please place some PDFs there.")
    print("Example: You can create a dummy PDF file for testing or download one.")
    exit("No PDFs found. Exiting.")
# Out:
# --- 2. Loading PDF Documents from 'data/pdfs' ---
# Loaded '03_Wills_and_Directives.pdf'
# Loaded '1-1-A.pdf'
# Loaded '1-2-a.pdf'
# Loaded '1095BHealthCoverageTaxDocument.pdf'
# Loaded '1200-13-01.20230419.pdf'
# Loaded '1200-13-02.20221004.pdf'
# Loaded '1200-13-03.pdf'
# Loaded '1200-13-04.20090719.pdf'
# Loaded '1200-13-05.20151220.pdf'
# Loaded '1200-13-06.pdf'
# Loaded '1200-13-07.pdf'
# Loaded '1200-13-08.pdf'
# Loaded '1200-13-09.pdf'
# Loaded '1200-13-10.pdf'
# Loaded '1200-13-11.20190403.pdf'
# Loaded '1200-13-12.pdf'
# Loaded '1200-13-13.20190403.pdf'
# Loaded '1200-13-13.20250202.pdf'
# Loaded '1200-13-14.20250202.pdf'
# Loaded '1200-13-15.20100829.pdf'
# Loaded '1200-13-16.20111128.pdf'
# Loaded '1200-13-17.20131113.pdf'
# Loaded '1200-13-18.20130415.pdf'
# Loaded '1200-13-19.20150503.pdf'
# Loaded '1200-13-20.20220811.pdf'
# Loaded '1200-13-21.20250202.pdf'
# Loaded '1915cWaiverAmendmentsPlainLanguageOverview.pdf'
# Loaded '2-1-a.pdf'
# Loaded '2-2-a.pdf'
# Loaded '2-6-a.pdf'
# Loaded '2011-SocialSecurityNumberPrivacy-TN.pdf'
# Loaded '2016_BBB_TN_ACEs_Initiative.pdf'
# Loaded '2019UpdateOfQualityImprovementStrategy.pdf'
# Loaded '2019UpdateToTheTennCareQualityStrategy.pdf'
# Loaded '2021QISUpdate.pdf'
# Loaded '2021QISUpdatePublicNotice.pdf'
# Loaded '2021UpdateQualityImprovementStrategy.pdf'
# Loaded '2021UpdateToQualityImprovementStrategy.pdf'
# Loaded '2022QISUpdatePublicNotice.pdf'
# Loaded '2022QISUpdatePublicNoticeFinal.pdf'
# Loaded '2022UpdateOfQualityImprovementStrategy.pdf'
# Loaded '2023QISUpdatePublicNotice.pdf'
# Loaded '2024QISUpdatePublicNotice.pdf'
# Loaded '2024QualityStrategyUpdateToPublicComment.pdf'
# Loaded '2709_protectingchildren.pdf'
# Loaded '3-1-a.pdf'
# Loaded '3-1-b.pdf'
# Loaded '3-1-c.pdf'
# Loaded '3-1-d.pdf'
# Loaded '3-1-e.pdf'
# Loaded '4-11-a.pdf'
# Loaded '4-14-b.pdf'
# Loaded '4-16-a.pdf'
# Loaded '4-17-a.pdf'
# Loaded '4-18-a.pdf'
# Loaded '4-19-a.pdf'
# Loaded '4-19-b.pdf'
# Loaded '4-19-c.pdf'
# Loaded '4-19-d.pdf'
# Loaded '4-19-e.pdf'
# Loaded '4-20-a.pdf'
# Loaded '4-22-a.pdf'
# Loaded '4-22-c.pdf'
# Loaded '4-30.pdf'
# Loaded '4-32-a.pdf'
# Loaded '4-33-a.pdf'
# Loaded '4-34-a.pdf'
# Loaded '4-35-a.pdf'
# Loaded '4-38.pdf'
# Loaded '4-39-a.pdf'
# Loaded '4-39.pdf'
# Loaded '4-40-a.pdf'
# Loaded '4-42-a.pdf'
# Loaded '5-1-a.pdf'
# Loaded '6086TN_CFSR_PIP_Approval_Letter.pdf'
# Loaded '7-2-a.pdf'
# Loaded '71-5-2505_et_seq.pdf'
# Loaded '80.3.4 - Authorization of Services.pdf'
# Loaded 'A-Child-Just-Told-Me-What-to-do-Infographic.pdf'
# Loaded 'ACES-FY18-Innovations-.pdf'
# Loaded 'ACEs_Case_Attention_Action.pdf'
# Loaded 'ACES_PreventionMitigationRecoveryAnticipatedImpacts.pdf'
# Loaded 'ACEs_Projects_Funded_for_FY20.pdf'
# Loaded 'ACEs_PROJECTS_FY17.pdf'
# Loaded 'ACEs_Project_Funded_FY22.pdf'
# Loaded 'AdditionalHCBSFlexibilities.pdf'
# Loaded 'AdditionalMaternalHealthBenefits.pdf'
# Loaded 'Adoption%20Assistance%20Brochure%20%203%201%202018%20-%20Updated%20-%20Confirmed%20by%20Program.pdf'
# Loaded 'AdoptionManual.pdf'
# Loaded 'AdultDentalBenefits.pdf'
# Loaded 'AdultDentalComprehensiveNotice.pdf'
# Loaded 'AmbulanceSPAPublicNotice.pdf'
# Loaded 'Amendment1DraftVersion.pdf'
# Loaded 'Amendment1PublicNotice.pdf'
# Loaded 'Amendment2ComprehensiveNotice.pdf'
# Loaded 'Amendment32.pdf'
# Loaded 'Amendment33.pdf'
# Loaded 'Amendment35.pdf'
# Loaded 'Amendment35ComprehensiveNotice.pdf'
# Loaded 'Amendment36.pdf'
# Loaded 'Amendment36ComprehensiveNotice.pdf'
# Loaded 'Amendment37.pdf'
# Loaded 'Amendment37ComprehensiveNotice.pdf'
# Loaded 'Amendment37ProposedChangesAttachmentG.pdf'
# Loaded 'Amendment38.pdf'
# Loaded 'Amendment38ComprehensiveNotice.pdf'
# Loaded 'Amendment39.pdf'
# Loaded 'Amendment39ComprehensiveNotice.pdf'
# Loaded 'Amendment3ComprehensiveNotice.pdf'
# Loaded 'Amendment3Draft.pdf'
# Loaded 'Amendment40.pdf'
# Loaded 'Amendment40ComprehensiveNotice.pdf'
# Loaded 'Amendment41.pdf'
# Loaded 'Amendment41ComprehensiveNotice.pdf'
# Loaded 'Amendment42ComprehensiveNotice.pdf'
# Loaded 'Amendment42FinalVersion.pdf'
# Loaded 'Amendment42MisunderstandingsClarifyingFacts.pdf'
# Loaded 'Amendment42RedlineVersion.pdf'
# Loaded 'Amendment43.pdf'
# Loaded 'Amendment43ComprehensivePublicNotice.pdf'
# Loaded 'Amendment44.pdf'
# Loaded 'Amendment44ComprehensivePublicNotice.pdf'
# Loaded 'Amendment4ComprehensiveNotice.pdf'
# Loaded 'Amendment4Draft.pdf'
# Loaded 'Amendment5ComprehensiveNotice.pdf'
# Loaded 'Amendment6ComprehensiveNotice.pdf'
# Loaded 'Amendment7ComprehensiveNotice.pdf'
# Loaded 'AnnualForum2020PublicNotice.pdf'
# Loaded 'AnnualForumPublicNotice.pdf'
# Loaded 'AnnualForumPublicNotice2025.pdf'
# Loaded 'AnnualForumPublicNotice22.pdf'
# Loaded 'AnnualForumPublicNotice23.pdf'
# Loaded 'AnnualForumPublicNoticeDemonstration.pdf'
# Loaded 'AnnualMonitoringReportPublicNotice.pdf'
# Loaded 'AppendixA_TN_Recruitment_Plan_FY23-24.pdf'
# Loaded 'AppendixB_TN_Health_Care_Oversight_Coord_2024.pdf'
# Loaded 'AppendixC_TN_Disaster_Plan_Supplemental_Doc_2024.pdf'
# Loaded 'AppendixD_TN_Training_Plan_2024.pdf'
# Loaded 'AppxA_Foster_Adoptive_Recruitment.pdf'
# Loaded 'AppxB_Health_Care_Plan.pdf'
# Loaded 'AppxC_Disaster_Plan.pdf'
# Loaded 'AppxD_Training_Plan.pdf'
# Loaded 'APSR_Approval_Letter.pdf'
# Loaded 'ARPublicNotice.pdf'
# Loaded 'ARPublicNotice18.pdf'
# Loaded 'aspr_fy2022.pdf'
# Loaded 'aspr_fy2023.pdf'
# Loaded 'AutoExempt-Attestation-Drug-List.pdf'
# Loaded 'BedHoldPublicNotice.pdf'
# Loaded 'BedHoldSPA.pdf'
# Loaded 'BehavioralHealthTransitions.pdf'
# Loaded 'ben06001.pdf'
# Loaded 'ben06002.pdf'
# Loaded 'ben07001.pdf'
# Loaded 'ben08001.pdf'
# Loaded 'ben11001.pdf'
# Loaded 'ben11002.pdf'
# Loaded 'ben15001.pdf'
# Loaded 'ben23001.pdf'
# Loaded 'benefitpackages.pdf'
# Loaded 'BESMARTSPAPublicNotice.pdf'
# Loaded 'BSB-Report.pdf'
# Loaded 'Building%20a%20Trauma%20Informed%20System%20of%20Care%20Toolkit.pdf'
# invalid pdf header: b'<!DOC'
# EOF marker not found
# invalid pdf header: b'<!DOC'
# EOF marker not found
# Loaded 'Building_Strong_BrainsOVERVIEW-MISSION.pdf'
# Error loading 'CFSRManual.pdf': Stream has ended unexpectedly
# Error loading 'CFSR_Roadshow.pdf': Stream has ended unexpectedly
# Loaded 'ChangeTennCareIIIProgramMaternalHealthEnhancements.pdf'
# Loaded 'CHIP2101Group.pdf'
# Loaded 'CHIPEligibilityProcessing.pdf'
# Loaded 'CHIPMAGIEligibility.pdf'
# Loaded 'CHIPNonFinancialEligibility.pdf'
# Loaded 'CHIPStatePlan.pdf'
# Loaded 'CHIPTitleXXIExpansion.pdf'
# Loaded 'ChiropracticSPAPublicNotice.pdf'
# Loaded 'CHOICESAtRiskDemonstrationGroup.pdf'
# Loaded 'CHOICESBenefitsComprehensiveNotice.pdf'
# Loaded 'CHOICESGroup3ComprehensiveNotice.pdf'
# Loaded 'CivilRightsNotice.pdf'
# Loaded 'ClinicalTrialsSPAPublicNotice.pdf'
# Loaded 'CMSApprovedEvaluationDesign.pdf'
# Loaded 'CMSApprovedEvaluationDesignHCBS.pdf'
# Loaded 'CMSApprovedEvaluationDesignRiskMitigation.pdf'
# Loaded 'CMSApprovedHCBSPHE.pdf'
# Loaded 'CMSApprovedInterimEvaluationReport.pdf'
# Loaded 'CMSApprovedPHERiskMitigationt.pdf'
# Loaded 'CMSAR040722.pdf'
# Loaded 'ComprehensiveNotice.pdf'
# Loaded 'ComprehensiveNotice33.pdf'
# Loaded 'ComprehensivePublicNotice.pdf'
# Loaded 'con05001.pdf'
# Loaded 'con06001.pdf'
# Loaded 'con07003.pdf'
# Loaded 'con08-002.pdf'
# Loaded 'con09001.pdf'
# Loaded 'con09002.pdf'
# Loaded 'con19001.pdf'
# Loaded 'ContinuousEligibilityForChildren.pdf'
# Loaded 'CoverageOfPregnantWomen.pdf'
# Loaded 'CoverKidsCopay (1).pdf'
# Loaded 'CoverKidsCopay.pdf'
# Loaded 'COVIDSPAPublicNotice.pdf'
# Loaded 'DARPublicNotice.pdf'
# Loaded 'DARPublicNotice20.pdf'
# Loaded 'DCS_CFSR-PIP_Round3.pdf'
# Loaded 'DCS_PracticeModel.pdf'
# Loaded 'DCS_Strategic_Plan.pdf'
# Loaded 'DentalServicesToBeCovered.pdf'
# Loaded 'download-TennCare-Dental-Health-Guide.pdf'
# Loaded 'DoYouNeedSpecialHelpEnglish.pdf'
# Loaded 'DoYouNeedSpecialHelpSpanish.pdf'
# Loaded 'DQ_TennCare_Dental_Guide.pdf'
# Loaded 'DQ_TennCare_Dental_Guide_Spanish.pdf'
# Loaded 'DraftDistributionMethodology.pdf'
# Loaded 'DraftDistributionMethodologyForUncompensatedCarePayments.pdf'
# Loaded 'DraftDistributionMethodologyUncompensatedCarePayments.pdf'
# Loaded 'DraftTennCareExtensionApplication.pdf'
# Loaded 'DraftVersionOfAmendment2.pdf'
# Loaded 'DraftVersionOfAmendment5.pdf'
# Loaded 'DraftVersionOfAmendment6.pdf'
# Loaded 'DraftVersionOfAmendment7.pdf'
# Loaded 'DraftVersionStatePlanAmendmentGraduateMedicalEducation.pdf'
# Loaded 'DraftVersionStatePlanAmendmentReimbursementRuralHealthClinicsFederallyQualifiedHealthCenters.pdf'
# Loaded 'DSHSPADraft.pdf'
# Loaded 'DSHSPAPublicNotice.pdf'
# Loaded 'ECF_Need-2-Know.pdf'
# Loaded 'EducatorGuide.pdf'
# Loaded 'eed06001.pdf'
# Loaded 'eed06002.pdf'
# Loaded 'eligibilityrefguide.pdf'
# Loaded 'ExtensionOfHCBSFlexibilities.pdf'
# Loaded 'factsheet.pdf'
# Loaded 'FARPublicNotice.pdf'
# Loaded 'foreignlanguageassistance.pdf'
# Loaded 'FPHandbook.pdf'
# Loaded 'FQHCRHCSPA.pdf'
# Loaded 'FQHCRHCSPAPublicNotice.pdf'
# Loaded 'GmeSpaDraft.pdf'
# Loaded 'GMESPAPublicNotice.pdf'
# Loaded 'GmeSpaPublicNotice2.pdf'
# Loaded 'GroupRegistrationInstructions.pdf'
# Loaded 'HCBSExpenditureCapsComprehensiveNotice.pdf'
# Loaded 'HCBSFlexibilitiesAmendment.pdf'
# Loaded 'HospitalFeeAmendmentComprehensiveNotice.pdf'
# Loaded 'HospitalFeeAmendmentDraft.pdf'
# Loaded 'HowToReportThirdPartyLiabilityInsuranceUpdates.pdf'
# Loaded 'IncarceratedJuvenilesSPAPublicNotice.pdf'
# Loaded 'indexstateplan.pdf'
# Loaded 'LactationSupportServicesSPAPublicNotice.pdf'
# Loaded 'Learn-more-about-your-benefits-(Arabic).pdf'
# Loaded 'Learn-more-about-your-benefits-(English)-TN.pdf'
# Loaded 'Learn-more-about-your-benefits-(Spanish)-TN.pdf'
# Loaded 'Legislative_Report_2024.pdf'
# Loaded 'Legislative_Report_2025.pdf'
# Loaded 'ManagedCareRiskMitigationAmendment.pdf'
# Loaded 'medappeal.pdf'
# Loaded 'Med_Planning_ICPC_Placements.pdf'
# Loaded 'Member-Handbook-(English).pdf'
# Loaded 'Member-Handbook-(Spanish).pdf'
# Loaded 'MethadoneClinicSPAPublicNotice.pdf'
# Loaded 'Multi-language-interpreter-services-TN.pdf'
# Loaded 'Nashville_M_Gagnon.pdf'
# Loaded 'Nat_KT_TN_ACES_Symposium.pdf'
# Loaded 'NCTDPrivateDutyNursingServices.pdf'
# Loaded 'NeedLanguageHelp.pdf'
# Loaded 'NFReimbSPAPublicNotice.pdf'
# Loaded 'NOCReimbursementRuralHealthClinicsFederallyQualifiedHealthCenters.pdf'
# Loaded 'NOCTennesseeEarlyInterventionSystemServices.pdf'
# Loaded 'nondiscrimination-notice.pdf'
# Loaded 'NoticeOfChangeIn1915cHCBSWaivers.pdf'
# Loaded 'NoticeOfChangeInMedicaidStatePlanCOVID19Vaccinations.pdf'
# Loaded 'NoticeOfChangeInMedicaidStatePlanIMDServices.pdf'
# Loaded 'NoticeOfChangeTennCareIIIDemonstrationUncompensatedCarePayments.pdf'
# Loaded 'NoticeOfChangeTo1915cWaiverAmendments.pdf'
# Loaded 'NoticeOfChangeTo1915cWaiverAmendments24.pdf'
# Loaded 'NoticeOfPublicForumOnProgressTennCareDemonstration.pdf'
# Loaded 'OK_TipsForKeepingKidsSafeOnline.pdf'
# Loaded 'OK_TipsForTalking_Infographic.pdf'
# Loaded 'org06002.pdf'
# Loaded 'org06003.pdf'
# Loaded 'org06004.pdf'
# Loaded 'org09002.pdf'
# Loaded 'org09003.pdf'
# Loaded 'pay06001.pdf'
# Loaded 'pay06002.pdf'
# Loaded 'pay08001.pdf'
# Loaded 'pay13001.pdf'
# Loaded 'pay14001.pdf'
# Loaded 'periodicity_schedule.pdf'
# Loaded 'PharmacyDispensingFeesSPAPublic%20Notice.pdf'
# Loaded 'PharmacyPublicNotice.pdf'
# Loaded 'pi08001.pdf'
# Loaded 'pi10-001.pdf'
# Loaded 'pi11-002.pdf'
# Loaded 'pi11001.pdf'
# Loaded 'pi11004.pdf'
# Loaded 'pi11005.pdf'
# Loaded 'pi12001.pdf'
# Loaded 'pi13001.pdf'
# Loaded 'PIP_Progress.pdf'
# Loaded 'PregnantWomenComprehensiveNotice.pdf'
# Loaded 'pro-22-001.pdf'
# Loaded 'pro-22-002.pdf'
# Loaded 'pro05001.pdf'
# Loaded 'pro07001.pdf'
# Loaded 'pro08001.pdf'
# Loaded 'pro11001.pdf'
# Loaded 'pro13-002.pdf'
# Loaded 'pro13001.pdf'
# Loaded 'pro16001.pdf'
# Loaded 'pro16002.pdf'
# Loaded 'pro19-001.pdf'
# Loaded 'pro22-003.pdf'
# Loaded 'pro23-001.pdf'
# Loaded 'pro23-002.pdf'
# Loaded 'ProfessionalDispensingFeesForPharmacies.pdf'
# Loaded 'ProposedAmendmentsToTennesseeSection1915cWaivers.pdf'
# Loaded 'ProposedAmendmentsToTennesseesSection1915c.pdf'
# Loaded 'ProposedDentalAmendmentsToTennesseeSection1915cHCBSWaivers.pdf'
# Loaded 'ProposedRenewalAmendmentsToTennesseesSection1915c24.pdf'
# Loaded 'ProviderDataValidationSurveyContractualRequirement.pdf'
# Loaded 'Public-Opinion-Report-ACES.pdf'
# Loaded 'PublicChapter869.pdf'
# Loaded 'PublicCommentsOnAmendment42.pdf'
# Loaded 'PublicForumProgressTennCareDemonstration.pdf'
# Loaded 'PublicForumProgressTennCareDemonstration2018.pdf'
# Loaded 'QualifiedNon-Citizens.pdf'
# Loaded 'RedlineDistributionMethodologyForUncompensatedCarePayments.pdf'
# Loaded 'RedlineDistributionMethodologyUncompensatedCarePayments.pdf'
# Loaded 'RedlineMethodology.pdf'
# Loaded 'RelativeCaregiverFlyer.pdf'
# Loaded 'RenewalPacketInstructionsEnglish.pdf'
# Loaded 'RequestWilsonHearingForm.pdf'
# Loaded 'RequestWilsonHearingFormSP.pdf'
# Loaded 'ResourcesDiabeticYouth.pdf'
# Loaded 'ResponsesPublicComment1915cRenewalAmendments.pdf'
# Loaded 'ResponsesPublicComment1915cWaiverAmendments.pdf'
# Loaded 'ResponsesToPublicComment20241915cWaiverRenewals.pdf'
# Loaded 'Sample_Menus.pdf'
# Loaded 'section1.pdf'
# Loaded 'section2.pdf'
# Loaded 'section3.pdf'
# Loaded 'section4.pdf'
# Loaded 'section5.pdf'
# Loaded 'section6.pdf'
# Loaded 'section7.pdf'
# Loaded 'SelectKids_Resource_Parent_Booklet.pdf'
# Loaded 'SharedSavingsQualityMeasuresProtocol.pdf'
# Loaded 'SigningFinancialGuarantor.pdf'
# Loaded 'SSIAdultRedeterminationProcess.pdf'
# Loaded 'SSPPAFDCIncomeStandards.pdf'
# Loaded 'SSPPApplication.pdf'
# Loaded 'SSPPChildrenWithNonIVEAdoptionAssistance.pdf'
# Loaded 'SSPPChildrenWithTitleIVEAdoptionAssistanceFosterCareOrGuardianshipCare.pdf'
# Loaded 'SSPPCitizenship.pdf'
# Loaded 'SSPPClosedEligibilityGroups.pdf'
# Loaded 'SSPPDeemedNewborns.pdf'
# Loaded 'SSPPEligibilityDeterminationsOfIndividualsAge65OrOlderOrWhoHaveBlindnessOrADisability.pdf'
# Loaded 'SSPPEligibilityProcess.pdf'
# Loaded 'SSPPExtendedMedicaidDueToSpousalSupportCollections.pdf'
# Loaded 'SSPPFormerFosterCareChildren.pdf'
# Loaded 'SSPPHandlingOfExcessIncomeSpenddown.pdf'
# Loaded 'SSPPHealthHome.pdf'
# Loaded 'SSPPIndividualsDeemedToBeReceivingSSI.pdf'
# Loaded 'SSPPIndividualsEligibleForCashExceptForInstitutionalization.pdf'
# Loaded 'SSPPIndividualsInInstitutionsEligibleUnderASpecialIncomeLevel.pdf'
# Loaded 'SSPPIndividualsNeedingTreatmentForBreastOrCervicalCancer.pdf'
# Loaded 'SSPPIndividualsReceivingHomeAndCommunityBasedWaiverServicesUnderInstitutionalRules.pdf'
# Loaded 'SSPPInfantsAndChildrenUnderAge19.pdf'
# Loaded 'SSPPMAGIBasedMethodologies.pdf'
# Loaded 'SSPPMedicallyNeedyChildrenUnderAge18.pdf'
# Loaded 'SSPPMedicallyNeedyIncomeLevel.pdf'
# Loaded 'SSPPMedicallyNeedyPregnantWomen.pdf'
# Loaded 'SSPPMedicallyNeedyReasonableClassificationsOfIndividualsUnderAge21.pdf'
# Loaded 'SSPPMedicallyNeedyResourceLevel.pdf'
# Loaded 'SSPPNonMAGIMethodologies.pdf'
# Loaded 'SSPPPACEParticipants.pdf'
# Loaded 'SSPPParentsAndOtherCaretakerRelatives.pdf'
# Loaded 'SSPPPregnantWomen.pdf'
# Loaded 'SSPPPresumptiveEligibility.pdf'
# Loaded 'SSPPQualifiedDisabledAndWorkingIndividuals.pdf'
# Loaded 'SSPPQualifiedMedicareBeneficiaries.pdf'
# Loaded 'SSPPQualifyingIndividuals.pdf'
# Loaded 'SSPPSingleStateAgency.pdf'
# Loaded 'SSPPSpecifiedLowIncomeMedicareBeneficiaries.pdf'
# Loaded 'SSPPSSIBeneficiaries.pdf'
# Loaded 'SSPPStateResidency.pdf'
# Loaded 'SSPPTransitionalMedicalAssistance.pdf'
# Loaded 'SSPPWorkingIndividualsUnder1619b.pdf'
# Loaded 'SupplementalPaymentDistributionMethodology.pdf'
# Loaded 'taglines.pdf'
# Loaded 'TCTip_Accessing_Services_OoS.pdf'
# Loaded 'TCTip_Access_Pharm_Benefits.pdf'
# Loaded 'TCTip_BH_Transition_thru_Project_Transition.pdf'
# Loaded 'TCTip_Emergency_Care_while_out_State.pdf'
# Loaded 'TCTip_Good_Cause_Exceptions.pdf'
# Loaded 'TCTip_Identify_Providers.pdf'
# Loaded 'TCTip_Immediate_Eligibility.pdf'
# Loaded 'TCTip_Nav_Medicaid_ICPC_Youth.pdf'
# Loaded 'TCTip_Services_Non-TennCare_eligible_youth.pdf'
# Loaded 'TEDSAdditionalFamilyMember.pdf'
# Loaded 'TEDSAdditionalFamilyMemberSP.pdf'
# Loaded 'TEDSPaperApp.pdf'
# Loaded 'TEDSPaperAppSp.pdf'
# Loaded 'TennCareAmendment42.pdf'
# Loaded 'TennCareAmendment42Executive%20Summary.pdf'
# Loaded 'TennCareAmendment42FAQs.pdf'
# Loaded 'TennCareAmendment42Overview.pdf'
# Loaded 'TennCareDraftAnnualReport18.pdf'
# Loaded 'TennCareDraftAnnualReport19.pdf'
# Loaded 'TennCareDraftAnnualReport20.pdf'
# Loaded 'TennCareEnrollmentEligibilityFacts.pdf'
# Loaded 'TennCareFinalAnnualReport18.pdf'
# Loaded 'TennCareKidsBackToSchoolFlyer.pdf'
# Loaded 'TennCareKidsBackToSchoolPoster.pdf'
# Loaded 'TennCareKidsFlyerTeen.pdf'
# Loaded 'TennCareKidsRecommendedImmunizations.pdf'
# Loaded 'TennCareOnlineServicesUpdates.pdf'
# Loaded 'TennCarePopQuizQuestionsAnswers.pdf'
# Loaded 'TennCareProviderQuickReferenceSheet.pdf'
# Loaded 'TennCareTip-Newborns_Applying_for_TNCare.pdf'
# Loaded 'tenncarewaiver.pdf'
# Loaded 'TennCare_Resources.pdf'
# Loaded 'tennercareflier.pdf'
# Loaded 'TennesseeSupplementalPaymentReconciliationMethodology.pdf'
# Loaded 'Tennessee_APSR_2021.pdf'
# Loaded 'TIPSReferenceGuide.pdf'
# Loaded 'TMAInsuranceWorkshopPresentation.pdf'
# Loaded 'TN%20ACEs%20PROJECTS%20FUNDED%20FOR%20FY19.pdf'
# Loaded 'TN%20Building%20Strong%20Brains%20Projects%202018.pdf'
# Loaded 'TN-Adult-Dental-FAQs.pdf'
# Loaded 'TN-AdvanceDirectivesLivingWill.pdf'
# Loaded 'TN-AsthmaActionPlan.pdf'
# Loaded 'TN-CareManagement.pdf'
# Loaded 'TN-CHOICESProviderDirectory-East.pdf'
# Loaded 'TN-CHOICESProviderDirectory-Middle.pdf'
# Loaded 'TN-CHOICESProviderDirectory-West.pdf'
# Loaded 'TN-ChronicObstructivePulmonaryDisease.pdf'
# Loaded 'TN-ECF-CHOICESProviderDirectory-East.pdf'
# Loaded 'TN-ECF-CHOICESProviderDirectory-Middle.pdf'
# Loaded 'TN-ECF-CHOICESProviderDirectory-West.pdf'
# Loaded 'TN-GeneralProviderDirectory-East.pdf'
# Loaded 'TN-GeneralProviderDirectory-Middle.pdf'
# Loaded 'TN-GeneralProviderDirectory-West.pdf'
# Loaded 'TN-Get-Internet-Flyer-EN.pdf'
# Loaded 'TN-HealthyFirstSteps.pdf'
# Loaded 'TN-Medicaid-Newsletter-Fall-2022-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Fall-2022-ES.pdf'
# Loaded 'TN-Medicaid-Newsletter-Fall-2023-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Fall-2023-ES.pdf'
# Loaded 'TN-Medicaid-Newsletter-Fall-2024-AR.pdf'
# Loaded 'TN-Medicaid-Newsletter-Fall-2024-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Fall-2024-ES.pdf'
# Loaded 'TN-Medicaid-Newsletter-Spring-2022-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Spring-2022-ES.pdf'
# Loaded 'TN-Medicaid-Newsletter-Spring-2023-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Spring-2023-ES.pdf'
# Loaded 'TN-Medicaid-Newsletter-Spring-2024-AR.pdf'
# Loaded 'TN-Medicaid-Newsletter-Spring-2024-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Spring-2024-ES.pdf'
# Loaded 'TN-Medicaid-Newsletter-Spring-2025-AR.pdf'
# Loaded 'TN-Medicaid-Newsletter-Spring-2025-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Spring-2025-ES.pdf'
# Loaded 'TN-Medicaid-Newsletter-Summer-2022-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Summer-2022-ES.pdf'
# Loaded 'TN-Medicaid-Newsletter-Summer-2023-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Summer-2023-ES.pdf'
# Loaded 'TN-Medicaid-Newsletter-Summer-2024-AR.pdf'
# Loaded 'TN-Medicaid-Newsletter-Summer-2024-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Summer-2024-ES.pdf'
# Loaded 'TN-Medicaid-Newsletter-Winter-2022-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Winter-2022-ES.pdf'
# Loaded 'TN-Medicaid-Newsletter-Winter-2023-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Winter-2023-ES.pdf'
# Loaded 'TN-Medicaid-Newsletter-Winter-2024-AR.pdf'
# Loaded 'TN-Medicaid-Newsletter-Winter-2024-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Winter-2024-ES.pdf'
# Loaded 'TN-Medicaid-Newsletter-Winter-2025-AR.pdf'
# Loaded 'TN-Medicaid-Newsletter-Winter-2025-EN.pdf'
# Loaded 'TN-Medicaid-Newsletter-Winter-2025-ES.pdf'
# Loaded 'TN-MemberHandbook-2024Addendum-EN.pdf'
# Loaded 'TN-MemberHandbook-Addendum-EN.pdf'
# Loaded 'TN-MemberHandbook-Addendum-ES.pdf'
# Loaded 'TN-MemberHandbook-EN.pdf'
# Loaded 'TN-MemberHandbook-ES.pdf'
# Loaded 'TN-NurseLine.pdf'
# Loaded 'TN-PCP-Change-Form.pdf'
# Loaded 'TN-QualityManagement.pdf'
# Loaded 'TN-Renewals-Alert.pdf'
# Loaded 'TN-Revised-Notice-Privacy-Practices-2013.pdf'
# Loaded 'TN-Safe-at-home.pdf'
# Loaded 'TN-TennCare-Diaper-Benefit-AR.pdf'
# Loaded 'TN-TennCare-Diaper-Benefit-EN.pdf'
# Loaded 'TN-TennCare-Diaper-Benefit-ES.pdf'
# Loaded 'TN-Tenncare-Transitions-Book1.pdf'
# Loaded 'TN-Tenncare-Transitions-Book2.pdf'
# Ignoring wrong pointing object 17 0 (offset 0)
# Ignoring wrong pointing object 60 0 (offset 0)
# Ignoring wrong pointing object 62 0 (offset 0)
# Ignoring wrong pointing object 67 0 (offset 0)
# Ignoring wrong pointing object 69 0 (offset 0)
# Ignoring wrong pointing object 71 0 (offset 0)
# Ignoring wrong pointing object 73 0 (offset 0)
# Ignoring wrong pointing object 77 0 (offset 0)
# Ignoring wrong pointing object 82 0 (offset 0)
# Ignoring wrong pointing object 84 0 (offset 0)
# Ignoring wrong pointing object 86 0 (offset 0)
# Ignoring wrong pointing object 88 0 (offset 0)
# Ignoring wrong pointing object 90 0 (offset 0)
# Ignoring wrong pointing object 92 0 (offset 0)
# Ignoring wrong pointing object 95 0 (offset 0)
# Ignoring wrong pointing object 101 0 (offset 0)
# Loaded 'TN-Tenncare-Transitions-Book3.pdf'
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 21 0 (offset 0)
# Ignoring wrong pointing object 53 0 (offset 0)
# Ignoring wrong pointing object 55 0 (offset 0)
# Ignoring wrong pointing object 57 0 (offset 0)
# Ignoring wrong pointing object 59 0 (offset 0)
# Ignoring wrong pointing object 63 0 (offset 0)
# Ignoring wrong pointing object 68 0 (offset 0)
# Ignoring wrong pointing object 70 0 (offset 0)
# Ignoring wrong pointing object 72 0 (offset 0)
# Ignoring wrong pointing object 74 0 (offset 0)
# Ignoring wrong pointing object 76 0 (offset 0)
# Ignoring wrong pointing object 82 0 (offset 0)
# Loaded 'TN-Tenncare-Transitions-Book4.pdf'
# Loaded 'TN-Tenncare-Transitions-Book5.pdf'
# Loaded 'TN-TransplantServices.pdf'
# Loaded 'TN-Wellness-Visits-Flyer.pdf'
# Loaded 'TNAdvance-Directives-Living-Wills-AR.pdf'
# Loaded 'TNCare_Flier.pdf'
# Loaded 'TN_2020%202024_CFSP_Approval_Letter_signed.pdf'
# Loaded 'TN_Child_Family_Service_Plan_2025-2029.pdf'
# Loaded 'TN_Civil_Rights_Notice.pdf'
# Loaded 'toc.pdf'
# Loaded 'UCPoolsComprehensiveNotice.pdf'
# Loaded 'UCPoolsComprehensiveNotice3.pdf'
# Loaded 'WellnessRoadMapAgeSevenUp.pdf'
# Loaded 'WellnessRoadMapAgeZeroToSix.pdf'
# Loaded 'WellnessRoadMapFull.pdf'

# %%
# --- 3. Split Documents into Chunks ---
print("\n--- 3. Splitting Documents into Chunks ---")
# Adjusted chunk_size and chunk_overlap for the Granite embedding model's 512 token limit.
# 400 characters is approximately 100-150 tokens, providing a safe buffer.
text_splitter = RecursiveCharacterTextSplitter(chunk_size=400, chunk_overlap=100)
chunks = text_splitter.split_documents(documents)
print(f"Original documents loaded: {len(documents)}")
print(f"Documents split into {len(chunks)} chunks.")
if chunks:
    print(f"First chunk example (first 200 chars):\n'{chunks[0].page_content[:200]}'")
else:
    exit("No chunks generated from documents. Exiting.")
# Out:
# --- 3. Splitting Documents into Chunks ---
# Original documents loaded: 28084
# Documents split into 229160 chunks.
# First chunk example (first 200 chars):
# 'LIVING WILLS
# A living will, originally designed to be completed when a person was diagnosed with a terminal illness, is an
# earlier version of an advance care directive document that tells a doctor ho'

# %%
# --- 4. Create Embeddings Model Instance (Nutanix Granite API) ---
print(f"\n--- 4. Creating Embeddings using Nutanix Granite Embedding API ('{EMBEDDING_API_MODEL_NAME}') ---")
try:
    embeddings_model = NutanixGraniteEmbeddings(
        api_key=NUTANIX_API_KEY,
        endpoint_url=NUTANIX_GRANITE_EMBEDDING_ENDPOINT,
        model_name=EMBEDDING_API_MODEL_NAME
    )
    # Test a dummy embedding to ensure API connection works and get dimension
    dummy_embedding = embeddings_model.embed_query("test connection")
    print(f"Nutanix Granite Embedding API connected successfully. Embedding dimension: {len(dummy_embedding)}")
except Exception as e:
    print(f"Error initializing or testing Nutanix Granite Embedding API: {e}")
    print("Please check your NUTANIX_API_KEY, endpoint URL, and internet connection.")
    exit()
# Out:
# --- 4. Creating Embeddings using Nutanix Granite Embedding API ('embedcpu') ---
# Nutanix Granite Embedding API connected successfully. Embedding dimension: 384

# %%
# --- 5. Create and Populate the Vector Database (ChromaDB) ---
print("\n--- 5. Creating and Populating the Vector Database (ChromaDB) ---")
try:
    vectorstore = Chroma.from_documents(
        documents=chunks,
        embedding=embeddings_model,
        persist_directory=CHROMA_DB_DIR
    )
    vectorstore.persist()
    print(f"Vector database created and populated with {len(chunks)} chunks.")
    print(f"ChromaDB persisted to '{CHROMA_DB_DIR}'")

    # --- Optional: Test the Vector Database ---
    print("\n--- Optional: Testing Vector Database with a Similarity Search ---")
    query = "What is the main topic of these documents?"
    docs_found = vectorstore.similarity_search(query, k=2)
    print(f"Query: '{query}'")
    print("\nTop 2 relevant chunks found:")
    for i, doc in enumerate(docs_found):
        print(f"--- Chunk {i+1} (Source: {doc.metadata.get('source', 'N/A')}, Page: {doc.metadata.get('page', 'N/A')}) ---")
        print(doc.page_content[:300] + "...")
        print("-" * 30)

except Exception as e:
    print(f"Error creating/populating ChromaDB: {e}")
    exit("Failed to create or populate the vector database.")
# Out:
# --- 5. Creating and Populating the Vector Database (ChromaDB) ---
# C:\Users\JoshStevenson\AppData\Local\Temp\ipykernel_3540\3102586629.py:9: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vectorstore.persist()
# Vector database created and populated with 229160 chunks.
# ChromaDB persisted to 'my_vector_db'
#
# --- Optional: Testing Vector Database with a Similarity Search ---
# Query: 'What is the main topic of these documents?'
#
# Top 2 relevant chunks found:
# --- Chunk 1 (Source: data/pdfs\TN-MemberHandbook-EN.pdf, Page: 185) ---
# These papers must be signed, and either witnessed or notarized. Once the papers are signed by
# everyone, it is your rule. It stays like this unless you change your mind.
# Table of contents...
# ------------------------------
# --- Chunk 2 (Source: data/pdfs\Public-Opinion-Report-ACES.pdf, Page: 2) ---
# ii
#
# Table of Contents
# Purpose and Methodology .......................................................................................................................... 1
# Findings and Discussion ........................................................................................................
# ------------------------------

# %%
# --- 6. Initialize the Remote LLM (Nutanix AI Endpoint) ---
print(f"\n--- 6. Initializing the Remote Language Model (Nutanix AI Endpoint: '{LLM_API_MODEL_NAME}') ---")
try:
    llm = ChatOpenAI(
        model=LLM_API_MODEL_NAME,
        temperature=0.0, # For more deterministic answers
        openai_api_key=NUTANIX_API_KEY,
        base_url=NUTANIX_LLM_ENDPOINT # ChatOpenAI will append /chat/completions to this base_url
    )
    print(f"Remote LLM '{llm.model_name}' initialized successfully via Nutanix AI Endpoint.")
except Exception as e:
    print(f"Error initializing remote LLM: {e}")
    print("Please ensure:")
    print("1. Your NUTANIX_API_KEY is correctly set.")
    print(f"2. The base endpoint URL '{NUTANIX_LLM_ENDPOINT}' is correct and accessible.")
    print(f"3. The model '{LLM_API_MODEL_NAME}' is available at the endpoint.")
    exit("Failed to initialize LLM. Exiting.")
# Out:
# --- 6. Initializing the Remote Language Model (Nutanix AI Endpoint: 'mobileyedemo') ---
# Remote LLM 'mobileyedemo' initialized successfully via Nutanix AI Endpoint.

# %%
# --- 7. Create Retriever and Build RAG Chain ---
print("\n--- 7. Creating Retriever and Building RAG Chain ---")
retriever = vectorstore.as_retriever(search_kwargs={"k": 3}) # Retrieve top 3 most relevant chunks
prompt = ChatPromptTemplate.from_messages([
    # Updated system prompt to explicitly request English output
    ("system", "Answer the user's question based on the provided context only. Respond concisely and in English.\nContext: {context}"),
    ("user", "{input}"),
])
document_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, document_chain)
print("RAG chain built successfully.")
# Out:
# --- 7. Creating Retriever and Building RAG Chain ---
# RAG chain built successfully.

# %%
# --- 8. Perform Interactive Inference ---
print("\n--- 8. Performing Interactive Inference with RAG ---")
print("Enter your questions below. Type 'exit' or 'quit' to end the session.")

while True:
    user_query = input("\nYour Question: ")
    if user_query.lower() in ["exit", "quit"]:
        print("Exiting interactive session. Goodbye!")
        break

    try:
        # Invoke the RAG chain with your query
        response = rag_chain.invoke({"input": user_query})
        print("\nLLM Answer:")
        print(response["answer"])

        print("\nRetrieved Context (Documents used by LLM):")
        if response["context"]:
            for j, doc in enumerate(response["context"]):
                print(f"  - Document {j+1} (Source: {doc.metadata.get('source', 'N/A')}, Page: {doc.metadata.get('page', 'N/A')})")
                print(f"    Content (first 200 chars): {doc.page_content[:200]}...")
        else:
            print("  No relevant documents were retrieved.")

    except Exception as e:
        print(f"Error during inference for query '{user_query}': {e}")
        print("Please ensure your Nutanix API key is valid and the LLM endpoint is accessible.")
        break # Breaking on error for interactive stability

print("\nConsolidated RAG Workflow Complete. Ready for your application!")
# Out:
# --- 8. Performing Interactive Inference with RAG ---
# Enter your questions below. Type 'exit' or 'quit' to end the session.
#
# LLM Answer:
# To find a doctor who takes TennCare insurance, you can:
#
# 1. Visit the TennCare website ([www.tn.gov/tenncare](http://www.tn.gov/tenncare)) and click on the "Find a Provider" tab.
# 2. Contact your local TennCare office or call 1-800-449-3866 (Monday-Friday, 8:00 AM - 6:00 PM EST) for assistance finding a provider in your area.
# 3. Ask your primary care physician or other healthcare provider if they participate in the TennCare program.
# 4. Check with your local hospital or healthcare system to see if they have a list of providers participating in TennCare.
# 5. You can also search online for "TennCare providers" along with your city or zip code to find a list of participating providers in your area.
#
# Retrieved Context (Documents used by LLM):
#   - Document 1 (Source: data/pdfs\pro08001.pdf, Page: 3)
#     Content (first 200 chars): TennCare for services that are covered by TennCare.
# Example: Johnny Brown is enrolled in TennCare Medicaid. He has insurance that allows him to
# visit his pediatrician for a copay of $10 per visit. J...
#   - Document 2 (Source: data/pdfs\pro08001.pdf, Page: 0)
#     Content (first 200 chars): 1. TennCare providers. Providers who are registered with TennCare and who accept some form of
# TennCare reimbursement for their services. Examples of TennCare providers include the
# following:
# • Prov...
#   - Document 3 (Source: data/pdfs\con09001.pdf, Page: 1)
#     Content (first 200 chars): T
# ennCare is a third party payer.  Some TennCare enrollees have both TennCare and other
# health insurance , which means there are two third party payers.  In  these cases,  one of the
# third parties i...
# API request failed: 400 Client Error: Bad Request for url: https://ai.nutanix.com/api/v1/embeddings
# Response status: 400
# Response text: {"errCode":"E1014","errMsg":"embeddings request validation failed: Provide a valid input. It must be a non-empty string or a non-empty list of strings"}
# Error during inference for query '': 400 Client Error: Bad Request for url: https://ai.nutanix.com/api/v1/embeddings
# Please ensure your Nutanix API key is valid and the LLM endpoint is accessible.
#
# Consolidated RAG Workflow Complete. Ready for your application!

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (1.45.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (2.2.6)
# Requirement already satisfied: packaging<25,>=20 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (2.3.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (11.2.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (4.14.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from altair<6,>=4.0->streamlit) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from altair<6,>=4.0->streamlit) (1.43.0)
# Requirement already satisfied: colorama in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from requests<3,>=2.27->streamlit) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\joshstevenson\miniconda3\envs\rag_nutanix_env\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
import sys
import os

# Get the path to the Python executable used by this Jupyter kernel
jupyter_python_executable = sys.executable

# Construct the likely path to the streamlit.exe script for this Python installation
# This is typically in a 'Scripts' subfolder next to the python.exe
streamlit_exe_path = os.path.join(
    os.path.dirname(jupyter_python_executable),
    "Scripts",
    "streamlit.exe"
)

# Fallback for common user-installed Python locations if the first path doesn't exist
if not os.path.exists(streamlit_exe_path):
    appdata_local_packages_path = os.path.join(
        os.path.expanduser("~"),
        "AppData", "Local", "Packages"
    )
    for root, dirs, files in os.walk(appdata_local_packages_path):
        if "Python" in root and "Scripts" in root and "streamlit.exe" in files:
            streamlit_exe_path = os.path.join(root, "streamlit.exe")
            break
    else:
        streamlit_exe_path = None # Not found in common paths

if streamlit_exe_path and os.path.exists(streamlit_exe_path):
    print(f"**FOUND STREAMLIT EXECUTABLE:**")
    print(f"  {streamlit_exe_path}")
else:
    print("ERROR: Could not find 'streamlit.exe'. Please ensure Streamlit is installed.")
    print("You might need to re-run the `!pip install streamlit` command in a fresh kernel.")
# Out:
# **FOUND STREAMLIT EXECUTABLE:**
#   c:\Users\JoshStevenson\miniconda3\envs\rag_nutanix_env\Scripts\streamlit.exe

# %%
import sys
import os
streamlit_exe_path = os.path.join(os.path.dirname(sys.executable), "Scripts", "streamlit.exe")
if not os.path.exists(streamlit_exe_path):
    # Fallback for common user-installed Python locations
    local_packages_dir = os.path.join(
        os.path.expanduser("~"), "AppData", "Local", "Packages",
        "PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0",
        "LocalCache", "local-packages", "Python312", "Scripts", "streamlit.exe"
    )
    if os.path.exists(local_packages_dir):
        streamlit_exe_path = local_packages_dir
    else:
        streamlit_exe_path = None
if streamlit_exe_path and os.path.exists(streamlit_exe_path):
    print(streamlit_exe_path)
else:
    print("Error: streamlit.exe path not found.")
# Out:
# c:\Users\JoshStevenson\miniconda3\envs\rag_nutanix_env\Scripts\streamlit.exe
